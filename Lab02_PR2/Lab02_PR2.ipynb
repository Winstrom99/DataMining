# %% [markdown]
# Cargar y procesar dataset

# %%
# %pip install gsppy

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from gsppy.gsp import GSP

# %%
df = pd.read_csv("./Navegacion_Web.csv")

# Convertir Timestamp a formato datetime y ordenar por usuario y tiempo
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.sort_values(by=['UserID', 'Timestamp'])

df.info()  # Ver columnas y tipos de datos
df.describe()  # Estadísticas generales
df_sorted = df.sort_values(by=["UserID", "Timestamp"])

# Agrupar por ClienteID y extraer la secuencia de acciones en una lista
sequences = df_sorted.groupby("UserID")["Action"].apply(list).tolist()

print(sequences)
print("")

################333


resultado1 = GSP(sequences).search(0.6)
print(resultado1)
print("")

resultado2 = GSP(sequences).search(0.2)
print(resultado2)
print("")
resultado3 = GSP(sequences).search(0.8)
print(resultado3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 5 to 58
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   UserID     60 non-null     object
#  1   Timestamp  60 non-null     datetime64[ns]
#  2   Action     60 non-null     object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 1.9+ KB
# [['Wishlist', 'View', 'Add to Cart', 'Purchase', 'Purchase', 'Wishlist', 'Purchase'], ['Contact', 'Purchase', 'Purchase', 'Add to Cart', 'Contact'], ['Contact', 'View', 'View', 'Purchase', 'View'], ['View', 'Contact', 'Contact', 'Add to Cart', 'View', 'Logout'], ['Search', 'Add to Cart', 'Contact', 'Add to Cart', 'View', 'Contact'], ['Add to Cart', 'Purchase', 'View', 'Add to Cart', 'Wishlist', 'Contact'], ['Wishlist', 'View', 'Add to Cart', 'Purchase', 'View', 'Search', 'View'], ['View', 'Add to Cart', 'Contact', 'Add to Cart', 'Purchase', 'Logout'], ['Add to Cart', 'Add to Cart', 'Purchase', 'Purchase', 'Purchase', 'Wishlist'], ['Contact', 'Add to Cart', 'Purchase', 'Add to Cart', 'Purchase', 'Wishlist']]
#
# [{('View',): 7, ('Add to Cart',): 9, ('Purchase',): 8, ('Contact',): 7}, {('Add to Cart', 'Purchase'): 6}]
#
# [{('Wishlist',): 5, ('View',): 7, ('Add to Cart',): 9, ('Purchase',): 8, ('Contact',): 7, ('Logout',): 2, ('Search',): 2}, {('Wishlist', 'View'): 2, ('View', 'Add to Cart'): 4, ('View', 'Contact'): 2, ('Add to Cart', 'View'): 2, ('Add to Cart', 'Purchase'): 6, ('Add to Cart', 'Contact'): 3, ('Purchase', 'Wishlist'): 3, ('Purchase', 'View'): 3, ('Purchase', 'Add to Cart'): 2, ('Contact', 'Add to Cart'): 4}, {('Wishlist', 'View', 'Add to Cart'): 2, ('View', 'Add to Cart', 'Purchase'): 2, ('Add to Cart', 'Purchase', 'View'): 2, ('Add to Cart', 'Contact', 'Add to Cart'): 2, ('Contact', 'Add to Cart', 'View'): 2, ('Contact', 'Add to Cart', 'Purchase'): 2}, {('Wishlist', 'View', 'Add to Cart', 'Purchase'): 2}]
#
# [{('Add to Cart',): 9, ('Purchase',): 8}]

# %%
# Función para aplicar GSP con diferentes valores de soporte
def aplicar_gsp(sequences, min_support):
    gsp = GSP(df).search(min_support)
    patterns = gsp.fit(sequences)
    return patterns

# Probar con diferentes valores de soporte
supports = [0.05, 0.1, 0.2]
patterns_dict = {}
for sup in supports:
    patterns_dict[sup] = aplicar_gsp(sequences, sup)
    print(f"Patrones con soporte {sup}:", patterns_dict[sup])

# Visualizar la distribución de acciones en la web
actions = [action for seq in sequences for action in seq]  # Extraer todas las acciones
counts = Counter(actions)

plt.figure(figsize=(8,5))
plt.bar(counts.keys(), counts.values())
plt.xlabel("Acciones en la Web")
plt.ylabel("Frecuencia")
plt.title("Distribución de Acciones en la Web")
plt.xticks(rotation=45)
plt.show()

# Eliminar una transacción clave y analizar cambios
df_filtered = df[df['Action'] != 'Purchase']  # Ejemplo: eliminar compras
sequences_filtered = df_filtered.groupby('UserID')['Action'].apply(list).tolist()
patterns_filtered = aplicar_gsp(sequences_filtered, 0.1)

print("Patrones después de eliminar la acción 'Purchase':", patterns_filtered)

# %%
df = pd.read_csv("./Navegacion_Web.csv")

# Convertir Timestamp a formato datetime y ordenar por usuario y tiempo
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.sort_values(by=['UserID', 'Timestamp'])

# Agrupar por usuario y obtener la secuencia de acciones
sequences = df.groupby('UserID')['Action'].apply(list).tolist()

# Función para aplicar GSP con diferentes valores de soporte
def aplicar_gsp(sequences, min_support):
    gsp = GSP(df).search(min_support)
    patterns = gsp.fit(sequences)
    return patterns

# Probar con diferentes valores de soporte
supports = [0.05, 0.1, 0.2]
patterns_dict = {}
for sup in supports:
    patterns_dict[sup] = aplicar_gsp(sequences, sup)
    print(f"Patrones con soporte {sup}:", patterns_dict[sup])

# Visualizar la distribución de acciones en la web
actions = [action for seq in sequences for action in seq]  # Extraer todas las acciones
counts = Counter(actions)

plt.figure(figsize=(8,5))
plt.bar(counts.keys(), counts.values())
plt.xlabel("Acciones en la Web")
plt.ylabel("Frecuencia")
plt.title("Distribución de Acciones en la Web")
plt.xticks(rotation=45)
plt.show()

# Eliminar una transacción clave y analizar cambios
df_filtered = df[df['Action'] != 'Purchase']  # Ejemplo: eliminar compras
sequences_filtered = df_filtered.groupby('UserID')['Action'].apply(list).tolist()
patterns_filtered = aplicar_gsp(sequences_filtered, 0.1)

print("Patrones después de eliminar la acción 'Purchase':", patterns_filtered)
